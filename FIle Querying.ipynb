-- %%
%python
files  = dbutils.fs.ls(f"/Volumes/databricks_simulated_retail_customer_data/v02/business_daily_events")
display(files)

-- %%
SELECT * FROM json.`dbfs:/Volumes/databricks_simulated_retail_customer_data/v02/business_daily_events/retail_business_events_2025-11-01.json`

-- %%
SELECT _metadata.file_path as source_file,* FROM json.`dbfs:/Volumes/databricks_simulated_retail_customer_data/v02/business_daily_events/retail_business_events_*.json`

-- %%
SELECT * FROM text.`dbfs:/Volumes/databricks_simulated_retail_customer_data/v02/business_daily_events`

-- %%
SELECT * FROM binaryFile.`dbfs:/Volumes/databricks_simulated_retail_customer_data/v02/business_daily_events/retail_business_events_*.json`

-- %%
-- add read_files method for csv file reading without creating view for ctas statement
SELECT * FROM read_files(
  '/Volumes/workspace/default/csvfiles/MismatchData.csv',
  format => 'csv',
  header => 'true',
  delimiter => ','
);
