# %%
import pandas as pd
df = pd.read_csv('/Volumes/databricks_airbnb_sample_data/v01/sf-listings/sf-airbnb.csv')
df.head(3)

# %%
display(df)

# %%
df["bedrooms"].hist(bins=20)

# %%
df.boxplot(["bedrooms","bathrooms"])

# %%
import seaborn as sbn

sbn.scatterplot(data=df, x="bedrooms",y="bathrooms")

# %%
sbn.regplot(data=df, x="bedrooms",y="bathrooms")
