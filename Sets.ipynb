# %%
#create set 
initial_Set = set()

initial_Set.add(1)
initial_Set.add(2)
initial_Set.add(3)
initial_Set.add(4)
initial_Set.add(3)
initial_Set.add(2)

print(initial_Set)

# %%
# remove first element from set and required element to delete

test_Set = set([1,2,3,4])
print(test_Set)

test_Set.pop()
print(test_Set)

test_Set.discard(4)
print(test_Set)
