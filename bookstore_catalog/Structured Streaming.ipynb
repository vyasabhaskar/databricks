-- %%
%python
(
spark.readStream.table("ecommerce_catalog.bookstore.books").createOrReplaceTempView("books_Streaming_view")
)

-- %%
USE CATALOG ecommerce_catalog;
USE SCHEMA bookstore;

CREATE OR REFRESH STREAMING TABLE books_streaming
AS SELECT * FROM STREAM(books);

-- %%
%python
from pyspark import pipelines as dp

@dp.table(
    name="books_streaming",
    trigger_type="continuous"
)
def books_streaming():
    return (
        spark.readStream.table("ecommerce_catalog.bookstore.books")
    )

-- %%
SELECT * FROM books_Streaming_view;
