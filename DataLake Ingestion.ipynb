-- %%
select current_catalog(), current_schema()

-- %%
LIST '/Volumes/databricks_simulated_e_commerce_clickstream_data/v01/raw/users-historical/'

-- %%
SELECT *

-- %%
SELECT * FROM

-- %%
SELECT * FROM parquet. `/Volumes/databricks_simulated_e_commerce_clickstream_data/v01/raw/users-historical/`;

-- %%
SELECT * FROM read_files('/Volumes/databricks_simulated_e_commerce_clickstream_data/v01/raw/users-historical/', format=>'parquet') LIMIT 10;

-- %%
DROP TABLE IF EXISTS history_users_bronze_ctas_rf;

CREATE TABLE history_users_bronze_ctas_rf
SELECT * FROM read_files('/Volumes/databricks_simulated_e_commerce_clickstream_data/v01/raw/users-historical/', format=>'parquet');

-- %%
SELECT * FROM history_users_bronze_ctas_rf

-- %%
%python

# read parquet files data into data frames
df = (spark.read.format('parquet').load('/Volumes/databricks_simulated_e_commerce_clickstream_data/v01/raw/users-historical/'))

# write data frame data into delta tables
(df. write.mode('overwrite').saveAsTable("workspace.default.history_users_bronze_ctas_rf_python"))

# read data from tables
users_bronze_tables = spark.table("workspace.default.history_users_bronze_ctas_rf_python")
users_bronze_tables.display()

-- %%
DROP TABLE IF EXISTS history_users_bronze_ctas_ci;

CREATE TABLE history_users_bronze_ctas_ci(
  user_id STRING,
  user_first_touch_timestamp BIGINT
);

COPY INTO history_users_bronze_ctas_ci
FROM '/Volumes/databricks_simulated_e_commerce_clickstream_data/v01/raw/users-historical/'
FILEFORMAT = PARQUET
COPY_OPTIONS('mergeSchema' = 'true');

SELECT * FROM history_users_bronze_ctas_ci

-- %%
DROP TABLE IF EXISTS history_users_bronze_ctas_ci_noschema;

CREATE TABLE history_users_bronze_ctas_ci_noschema;

COPY INTO history_users_bronze_ctas_ci_noschema
FROM '/Volumes/databricks_simulated_e_commerce_clickstream_data/v01/raw/users-historical/'
FILEFORMAT = PARQUET
COPY_OPTIONS('mergeSchema' = 'true');

SELECT * FROM history_users_bronze_ctas_ci_noschema;

-- %%
COPY INTO history_users_bronze_ctas_ci_noschema
FROM '/Volumes/databricks_simulated_e_commerce_clickstream_data/v01/raw/users-historical/'
FILEFORMAT = PARQUET
COPY_OPTIONS('mergeSchema' = 'true');

-- %%
SELECT * FROM read_files('/Volumes/workspace/default/steams/Electric_Vehicle_Population_Data.csv', FORMAT=> 'csv',sep => ',', header => true);

-- %%
CREATE OR REFRESH STREAMING TABLE streaming_electric_vehicles_csv
SCHEDULE EVERY 1 hour
AS 
SELECT * FROM STREAM read_files(
  '/Volumes/workspace/default/steams', 'csv', map('sep', ',', 'header', 'true')
);

-- %%
select * from streaming_electric_vehicles_csv where Model_Year = 2026;

-- %%
DESCRIBE TABLE EXTENDED workspace.default.streaming_electric_vehicles_csv

-- %%
DESCRIBE HISTORY workspace.default.streaming_electric_vehicles_csv

-- %%
REFRESH STREAMING TABLE streaming_electric_vehicles_csv
